# %% [markdown]
# # Simulación del Truco

# %% [markdown]
# Las **cartas** deben registra el numero, palo y valor de la carta.
# El valor debe reflejar la jerarquía de las cartas en el juego del truco.

# %%
def calcular_valor(numero, palo):
    
    jerarquia = {
        (1, 'espada'): 14,
        (1, 'basto'): 13,
        (7, 'espada'): 12,
        (7, 'oro'): 11,
        (3, 'copa'): 10, (3, 'espada'): 10, (3, 'oro'): 10, (3, 'basto'): 10,
        (2, 'copa'): 9, (2, 'espada'): 9, (2, 'oro'): 9, (2, 'basto'): 9,
        (1, 'copa'): 8, (1, 'oro'): 8,
        (12, 'copa'): 7, (12, 'espada'): 7, (12, 'oro'): 7, (12, 'basto'): 7,
        (11, 'copa'): 6, (11, 'espada'): 6, (11, 'oro'): 6, (11, 'basto'): 6,
        (10, 'copa'): 5, (10, 'espada'): 5, (10, 'oro'): 5, (10, 'basto'): 5,
        (7, 'copa'): 4, (7, 'basto'): 4,
        (6, 'copa'): 3, (6, 'espada'): 3, (6, 'oro'): 3, (6, 'basto'): 3,
        (5, 'copa'): 2, (5, 'espada'): 2, (5, 'oro'): 2, (5, 'basto'): 2,
        (4, 'copa'): 1, (4, 'espada'): 1, (4, 'oro'): 1, (4, 'basto'): 1
    }
    
    
    return jerarquia.get((numero, palo), numero)


class Carta:
    def __init__(self, numero, palo):
        self.numero = numero
        self.palo = palo
        self.valor = calcular_valor(numero, palo)

    def __str__(self):
        return f"{self.numero} de {self.palo} (valor: {self.valor})"
 

c = Carta(1, "oro")

# %% [markdown]
# **Mazo**: Representan las cartas españolas de 1 al 12, en los palos de oro, copa, espada y basto.
#
# Debe existir una función que permita barajar las cartas.
# y otra función que permita repartir las cartas a los jugadores.

# %%
import random

class Mazo:
    def __init__(self):
        self.cartas = [Carta(numero, palo) for numero in range(1, 13)
                       for palo in ["oro", "copa", "espada", "basto"] if numero != 8 and numero != 9]

    def mezclar(self):
        random.shuffle(self.cartas)

    def repartir(self, cantidad):
        return [self.cartas.pop() for _ in range(cantidad)]

# %% [markdown]
# **Jugador**: Deben tener un nombre y las cartas que tiene en la mano. Debe acumular los puntos ganados.
#
# Nota: Para simplificar el problema, el jugador elige la carta a jugar de forma aleatoria.

# %%
class Jugador:
    def __init__(self, nombre):
        self.nombre = nombre
        self.cartas = []
        self.puntos = 0

    def recibir_cartas(self, cartas):
        self.cartas = cartas

    def jugar_carta(self):
        return self.cartas.pop(random.randint(0, len(self.cartas) - 1))

    def __str__(self):
        return f"{self.nombre} (puntos: {self.puntos})"

# %% [markdown]
# **Partida**: Debe tener dos jugadores, un mazo de cartas y un puntaje. Debe permitir jugar una carta por ronda y definir el ganador de la ronda. Debe permitir jugar hasta que se terminen las cartas del mazo.

# %%
class Partida:
    def __init__(self, jugador1, jugador2):
        self.jugador1 = jugador1
        self.jugador2 = jugador2
        self.mazo = Mazo()

    def jugar_ronda(self):
   
        carta_j1 = self.jugador1.jugar_carta()
        carta_j2 = self.jugador2.jugar_carta()

       
        print(f"{chr(27)+"[1;31m"}{self.jugador1.nombre}{chr(27)+"[1;37m"} juega {carta_j1}")
        if carta_j1.valor  == 14:
            print(f"{chr(27)+"[1;33m"}----------{self.jugador1.nombre.upper()} JUGO EL MACHO----------{chr(27)+"[1;37m"}")
        
        print(f"{chr(27)+"[1;36m"}{self.jugador2.nombre}{chr(27)+"[1;37m"} juega {carta_j2}")
        if carta_j2.valor  == 14:
            print(f"{chr(27)+"[1;33m"}----------{self.jugador2.nombre.upper()} JUGO EL MACHO----------{chr(27)+"[1;37m"}")

       
        if carta_j1.valor > carta_j2.valor:
            print(f"{chr(27)+"[1;31m"}{self.jugador1.nombre} gana la ronda")
            self.jugador1.puntos += 1
        elif carta_j2.valor > carta_j1.valor:
            print(f"{chr(27)+"[1;36m"}{self.jugador2.nombre} gana la ronda")
            self.jugador2.puntos += 1
        else:
            print(f"{chr(27)+"[1;35m"}Empate en la ronda")

    def jugar(self):

        while self.jugador1.puntos < 15 and self.jugador2.puntos < 15:
            print(f"{chr(27)+"[1;35m"} Nueva ronda:")

            self.mazo = Mazo()
            self.mazo.mezclar()
            self.jugador1.recibir_cartas(self.mazo.repartir(3))
            self.jugador2.recibir_cartas(self.mazo.repartir(3))


            for _ in range(3):
                self.jugar_ronda()

 
                if self.jugador1.puntos >= 15 or self.jugador2.puntos >= 15:
                    break

            print(f"{chr(27)+"[1;32m"}Puntos: {chr(27)+"[1;31m"}{self.jugador1.nombre}: {self.jugador1.puntos}{chr(27)+"[1;37m"} , {chr(27)+"[1;36m"}{self.jugador2.nombre}: {self.jugador2.puntos}")


        ganador = self.jugador1 if self.jugador1.puntos >= 15 else self.jugador2
        print(f"\n¡{ganador.nombre} ha ganado la partida con {ganador.puntos} puntos!")



p = Partida(Jugador("Juan"), Jugador("Pedro"))
p.jugar()
# Out:
#  Nueva ronda:
# Juan juega 10 de copa (valor: 5)
# Pedro juega 3 de espada (valor: 10)
# Pedro gana la ronda
# Juan juega 7 de copa (valor: 4)
# Pedro juega 1 de oro (valor: 8)
# Pedro gana la ronda
# Juan juega 7 de oro (valor: 11)
# Pedro juega 7 de espada (valor: 12)
# Pedro gana la ronda
# Puntos: Juan: 0 , Pedro: 3
#  Nueva ronda:
# Juan juega 6 de copa (valor: 3)
# Pedro juega 4 de copa (valor: 1)
# Juan gana la ronda
# Juan juega 5 de oro (valor: 2)
# Pedro juega 7 de espada (valor: 12)
# Pedro gana la ronda
# Juan juega 11 de espada (valor: 6)
# Pedro juega 2 de oro (valor: 9)
# Pedro gana la ronda
# Puntos: Juan: 1 , Pedro: 5
#  Nueva ronda:
# Juan juega 3 de oro (valor: 10)
# Pedro juega 12 de copa (valor: 7)
# Juan gana la ronda
# Juan juega 12 de espada (valor: 7)
# Pedro juega 1 de espada (valor: 14)
# ----------PEDRO JUGO EL MACHO----------
# Pedro gana la ronda
# Juan juega 7 de copa (valor: 4)
# Pedro juega 5 de espada (valor: 2)
# Juan gana la ronda
# Puntos: Juan: 3 , Pedro: 6
#  Nueva ronda:
# Juan juega 5 de copa (valor: 2)
# Pedro juega 11 de oro (valor: 6)
# Pedro gana la ronda
# Juan juega 3 de espada (valor: 10)
# Pedro juega 10 de copa (valor: 5)
# Juan gana la ronda
# Juan juega 6 de oro (valor: 3)
# Pedro juega 4 de oro (valor: 1)
# Juan gana la ronda
# Puntos: Juan: 5 , Pedro: 7
#  Nueva ronda:
# Juan juega 2 de copa (valor: 9)
# Pedro juega 5 de copa (valor: 2)
# Juan gana la ronda
# Juan juega 7 de espada (valor: 12)
# Pedro juega 4 de copa (valor: 1)
# Juan gana la ronda
# Juan juega 11 de basto (valor: 6)
# Pedro juega 5 de espada (valor: 2)
# Juan gana la ronda
# Puntos: Juan: 8 , Pedro: 7
#  Nueva ronda:
# Juan juega 5 de copa (valor: 2)
# Pedro juega 4 de basto (valor: 1)
# Juan gana la ronda
# Juan juega 7 de oro (valor: 11)
# Pedro juega 3 de basto (valor: 10)
# Juan gana la ronda
# Juan juega 3 de oro (valor: 10)
# Pedro juega 3 de espada (valor: 10)
# Empate en la ronda
# Puntos: Juan: 10 , Pedro: 7
#  Nueva ronda:
# Juan juega 4 de basto (valor: 1)
# Pedro juega 11 de copa (valor: 6)
# Pedro gana la ronda
# Juan juega 12 de basto (valor: 7)
# Pedro juega 6 de basto (valor: 3)
# Juan gana la ronda
# Juan juega 5 de copa (valor: 2)
# Pedro juega 2 de basto (valor: 9)
# Pedro gana la ronda
# Puntos: Juan: 11 , Pedro: 9
#  Nueva ronda:
# Juan juega 1 de espada (valor: 14)
# ----------JUAN JUGO EL MACHO----------
# Pedro juega 12 de oro (valor: 7)
# Juan gana la ronda
# Juan juega 2 de espada (valor: 9)
# Pedro juega 12 de espada (valor: 7)
# Juan gana la ronda
# Juan juega 10 de copa (valor: 5)
# Pedro juega 7 de copa (valor: 4)
# Juan gana la ronda
# Puntos: Juan: 14 , Pedro: 9
#  Nueva ronda:
# Juan juega 10 de oro (valor: 5)
# Pedro juega 11 de oro (valor: 6)
# Pedro gana la ronda
# Juan juega 12 de oro (valor: 7)
# Pedro juega 3 de basto (valor: 10)
# Pedro gana la ronda
# Juan juega 12 de basto (valor: 7)
# Pedro juega 2 de oro (valor: 9)
# Pedro gana la ronda
# Puntos: Juan: 14 , Pedro: 12
#  Nueva ronda:
# Juan juega 5 de espada (valor: 2)
# Pedro juega 11 de copa (valor: 6)
# Pedro gana la ronda
# Juan juega 4 de basto (valor: 1)
# Pedro juega 3 de copa (valor: 10)
# Pedro gana la ronda
# Juan juega 2 de oro (valor: 9)
# Pedro juega 5 de oro (valor: 2)
# Juan gana la ronda
# Puntos: Juan: 15 , Pedro: 14
#
# ¡Juan ha ganado la partida con 15 puntos!
