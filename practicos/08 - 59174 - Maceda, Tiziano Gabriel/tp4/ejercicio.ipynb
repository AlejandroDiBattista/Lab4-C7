# %% [markdown]
# # Simulación del Truco

# %% [markdown]
# Las **cartas** deben registra el numero, palo y valor de la carta.
# El valor debe reflejar la jerarquía de las cartas en el juego del truco.

# %%
import random

def calcular_valor(numero, palo):
    
    valores = {
       (1, 'espada'): 14, (1, 'basto'): 13, (7, 'espada'): 12, (7, 'oro'): 11,
        (3, 'copa'): 10, (3, 'espada'): 10, (3, 'oro'): 10, (3, 'basto'): 10,
        (2, 'copa'): 9, (2, 'espada'): 9, (2, 'oro'): 9, (2, 'basto'): 9,
        (1, 'copa'): 8, (1, 'oro'): 8,
        (12, 'copa'): 7, (12, 'espada'): 7, (12, 'oro'): 7, (12, 'basto'): 7,
        (11, 'copa'): 6, (11, 'espada'): 6, (11, 'oro'): 6, (11, 'basto'): 6,
        (10, 'copa'): 5, (10, 'espada'): 5, (10, 'oro'): 5, (10, 'basto'): 5,
        (7, 'copa'): 4, (7, 'basto'): 4,
        (6, 'copa'): 3, (6, 'espada'): 3, (6, 'oro'): 3, (6, 'basto'): 3,
        (5, 'copa'): 2, (5, 'espada'): 2, (5, 'oro'): 2, (5, 'basto'): 2,
        (4, 'copa'): 1, (4, 'espada'): 1, (4, 'oro'): 1, (4, 'basto'): 1,
    }
    return valores.get((numero, palo), 0) 

emojis = {'oro': '🌞', 
          'copa': '🍷', 
          'espada': '🗡️', 
          'basto': '🥖'
        }

class Carta:
    def __init__(self, numero, palo):
        self.numero = numero
        self.palo = palo
        self.valor = calcular_valor(numero, palo)

    def __repr__(self):
        return f"{self.numero} de {emojis [self.palo]}"

    def __gt__(self, other):
       
        return self.valor > other.valor

class Mazo:
    def __init__(self):
        self.cartas = [Carta(numero, palo) for numero in range(1, 13) for palo in ["oro", "copa", "espada", "basto"] if numero != 8 and numero != 9]
    
    def mezclar(self):
        random.shuffle(self.cartas)

    def repartir(self, cantidad):
        return [self.cartas.pop() for _ in range(cantidad)] if len(self.cartas) >= cantidad else []


class Jugador:
    def __init__(self, nombre):
        self.nombre = nombre
        self.cartas_en_mano = []
        self.puntos = 0

    def __repr__(self):
        return self.nombre

    def recibir_cartas(self, cartas):
        self.cartas_en_mano = cartas

    def jugar_carta(self):
        return self.cartas_en_mano.pop(random.randint(0, len(self.cartas_en_mano)-1)) if self.cartas_en_mano else None


class Partida:
    def __init__(self, jugador1, jugador2):
        self.jugadores = [jugador1, jugador2]
        self.mazo = Mazo()

    def jugar_ronda(self):
        
        return [[j.jugar_carta() for j in self.jugadores] for _ in range(3)]
    
    def evaluar_jugada(self, jugadas):
        
        ganadas = [ sum(1 for c1, c2 in jugadas if c1 > c2),
                   sum(1 for c1, c2 in jugadas if c2 > c1)]
        
       
        for ganadas, jugador in zip(ganadas, self.jugadores):
            if ganadas >= 2:
                jugador.puntos += 1
                print(f"{jugador} gana la ronda")

    def puntajes(self):
        
        print(f"\nPuntos:")
        for jugador in self.jugadores:
            print(f" - {jugador}: {jugador.puntos}")
        print('-' * 20)

    def jugar(self):
        ronda = 0
        
        while all(j.puntos < 15 for j in self.jugadores):
            self.mazo = Mazo()  
            self.mazo.mezclar()  
            ronda += 1
            print(f"Ronda {ronda} {[jugador for jugador in self.jugadores]}")

            for jugador in self.jugadores:
                jugador.recibir_cartas(self.mazo.repartir(3))
            
            jugadas = self.jugar_ronda()
            for jugada in jugadas:
                print(' ', jugada)
            
            self.evaluar_jugada(jugadas)
            
            self.puntajes()

        for jugador in self.jugadores:
            if jugador.puntos >= 15:
                print(f"{jugador} gana la partida")

p = Partida(Jugador("👤 jugador1"), Jugador("👤 jugador2"))
p.jugar()
# Out:
# Ronda 1 [👤 jugador1, 👤 jugador2]
#   [1 de 🥖, 7 de 🍷]
#   [6 de 🗡️, 2 de 🗡️]
#   [5 de 🗡️, 2 de 🍷]
# 👤 jugador2 gana la ronda
#
# Puntos:
#  - 👤 jugador1: 0
#  - 👤 jugador2: 1
# --------------------
# Ronda 2 [👤 jugador1, 👤 jugador2]
#   [2 de 🥖, 12 de 🌞]
#   [2 de 🗡️, 12 de 🥖]
#   [4 de 🍷, 11 de 🍷]
# 👤 jugador1 gana la ronda
#
# Puntos:
#  - 👤 jugador1: 1
#  - 👤 jugador2: 1
# --------------------
# Ronda 3 [👤 jugador1, 👤 jugador2]
#   [10 de 🗡️, 12 de 🥖]
#   [10 de 🍷, 11 de 🌞]
#   [1 de 🥖, 11 de 🗡️]
# 👤 jugador2 gana la ronda
#
# Puntos:
#  - 👤 jugador1: 1
#  - 👤 jugador2: 2
# --------------------
# Ronda 4 [👤 jugador1, 👤 jugador2]
#   [11 de 🗡️, 4 de 🗡️]
#   [1 de 🌞, 10 de 🗡️]
#   [6 de 🥖, 12 de 🍷]
# 👤 jugador1 gana la ronda
#
# Puntos:
#  - 👤 jugador1: 2
#  - 👤 jugador2: 2
# --------------------
# Ronda 5 [👤 jugador1, 👤 jugador2]
#   [7 de 🗡️, 4 de 🗡️]
#   [10 de 🗡️, 2 de 🍷]
#   [3 de 🥖, 3 de 🌞]
#
# Puntos:
#  - 👤 jugador1: 2
#  - 👤 jugador2: 2
# --------------------
# Ronda 6 [👤 jugador1, 👤 jugador2]
#   [5 de 🥖, 3 de 🍷]
#   [6 de 🌞, 11 de 🥖]
#   [12 de 🌞, 4 de 🥖]
# 👤 jugador2 gana la ronda
#
# Puntos:
#  - 👤 jugador1: 2
#  - 👤 jugador2: 3
# --------------------
# Ronda 7 [👤 jugador1, 👤 jugador2]
#   [4 de 🍷, 10 de 🗡️]
#   [2 de 🍷, 10 de 🍷]
#   [5 de 🗡️, 2 de 🥖]
# 👤 jugador2 gana la ronda
#
# Puntos:
#  - 👤 jugador1: 2
#  - 👤 jugador2: 4
# --------------------
# Ronda 8 [👤 jugador1, 👤 jugador2]
#   [6 de 🍷, 3 de 🗡️]
#   [3 de 🌞, 3 de 🥖]
#   [12 de 🗡️, 11 de 🥖]
#
# Puntos:
#  - 👤 jugador1: 2
#  - 👤 jugador2: 4
# --------------------
# Ronda 9 [👤 jugador1, 👤 jugador2]
#   [4 de 🌞, 5 de 🗡️]
#   [1 de 🥖, 1 de 🗡️]
#   [7 de 🥖, 2 de 🍷]
# 👤 jugador2 gana la ronda
#
# Puntos:
#  - 👤 jugador1: 2
#  - 👤 jugador2: 5
# --------------------
# Ronda 10 [👤 jugador1, 👤 jugador2]
#   [5 de 🌞, 2 de 🌞]
#   [7 de 🍷, 1 de 🍷]
#   [4 de 🍷, 12 de 🌞]
# 👤 jugador2 gana la ronda
#
# Puntos:
#  - 👤 jugador1: 2
#  - 👤 jugador2: 6
# --------------------
# Ronda 11 [👤 jugador1, 👤 jugador2]
#   [12 de 🌞, 1 de 🥖]
#   [3 de 🗡️, 11 de 🌞]
#   [7 de 🥖, 5 de 🌞]
# 👤 jugador1 gana la ronda
#
# Puntos:
#  - 👤 jugador1: 3
#  - 👤 jugador2: 6
# --------------------
# Ronda 12 [👤 jugador1, 👤 jugador2]
#   [7 de 🥖, 6 de 🗡️]
#   [6 de 🥖, 5 de 🥖]
#   [2 de 🌞, 3 de 🥖]
# 👤 jugador1 gana la ronda
#
# Puntos:
#  - 👤 jugador1: 4
#  - 👤 jugador2: 6
# --------------------
# Ronda 13 [👤 jugador1, 👤 jugador2]
#   [10 de 🗡️, 5 de 🌞]
#   [3 de 🌞, 11 de 🥖]
#   [1 de 🗡️, 6 de 🍷]
# 👤 jugador1 gana la ronda
#
# Puntos:
#  - 👤 jugador1: 5
#  - 👤 jugador2: 6
# --------------------
# Ronda 14 [👤 jugador1, 👤 jugador2]
#   [10 de 🍷, 12 de 🥖]
#   [4 de 🥖, 12 de 🍷]
#   [3 de 🥖, 6 de 🗡️]
# 👤 jugador2 gana la ronda
#
# Puntos:
#  - 👤 jugador1: 5
#  - 👤 jugador2: 7
# --------------------
# Ronda 15 [👤 jugador1, 👤 jugador2]
#   [3 de 🍷, 7 de 🍷]
#   [2 de 🥖, 3 de 🗡️]
#   [12 de 🗡️, 2 de 🍷]
# 👤 jugador2 gana la ronda
#
# Puntos:
#  - 👤 jugador1: 5
#  - 👤 jugador2: 8
# --------------------
# Ronda 16 [👤 jugador1, 👤 jugador2]
#   [3 de 🥖, 2 de 🌞]
#   [1 de 🥖, 10 de 🍷]
#   [12 de 🌞, 10 de 🗡️]
# 👤 jugador1 gana la ronda
#
# Puntos:
#  - 👤 jugador1: 6
#  - 👤 jugador2: 8
# --------------------
# Ronda 17 [👤 jugador1, 👤 jugador2]
#   [7 de 🗡️, 6 de 🗡️]
#   [3 de 🌞, 10 de 🗡️]
#   [7 de 🥖, 12 de 🗡️]
# 👤 jugador1 gana la ronda
#
# Puntos:
#  - 👤 jugador1: 7
#  - 👤 jugador2: 8
# --------------------
# Ronda 18 [👤 jugador1, 👤 jugador2]
#   [5 de 🥖, 11 de 🍷]
#   [10 de 🗡️, 11 de 🗡️]
#   [6 de 🍷, 6 de 🗡️]
# 👤 jugador2 gana la ronda
#
# Puntos:
#  - 👤 jugador1: 7
#  - 👤 jugador2: 9
# --------------------
# Ronda 19 [👤 jugador1, 👤 jugador2]
#   [4 de 🌞, 6 de 🥖]
#   [5 de 🗡️, 1 de 🗡️]
#   [1 de 🍷, 10 de 🥖]
# 👤 jugador2 gana la ronda
#
# Puntos:
#  - 👤 jugador1: 7
#  - 👤 jugador2: 10
# --------------------
# Ronda 20 [👤 jugador1, 👤 jugador2]
#   [6 de 🌞, 5 de 🌞]
#   [3 de 🗡️, 7 de 🍷]
#   [6 de 🥖, 11 de 🥖]
# 👤 jugador1 gana la ronda
#
# Puntos:
#  - 👤 jugador1: 8
#  - 👤 jugador2: 10
# --------------------
# Ronda 21 [👤 jugador1, 👤 jugador2]
#   [6 de 🗡️, 12 de 🌞]
#   [1 de 🗡️, 7 de 🥖]
#   [1 de 🍷, 11 de 🍷]
# 👤 jugador1 gana la ronda
#
# Puntos:
#  - 👤 jugador1: 9
#  - 👤 jugador2: 10
# --------------------
# Ronda 22 [👤 jugador1, 👤 jugador2]
#   [11 de 🗡️, 2 de 🥖]
#   [4 de 🍷, 11 de 🍷]
#   [1 de 🌞, 6 de 🥖]
# 👤 jugador2 gana la ronda
#
# Puntos:
#  - 👤 jugador1: 9
#  - 👤 jugador2: 11
# --------------------
# Ronda 23 [👤 jugador1, 👤 jugador2]
#   [11 de 🍷, 10 de 🗡️]
#   [4 de 🌞, 1 de 🗡️]
#   [6 de 🥖, 3 de 🍷]
# 👤 jugador2 gana la ronda
#
# Puntos:
#  - 👤 jugador1: 9
#  - 👤 jugador2: 12
# --------------------
# Ronda 24 [👤 jugador1, 👤 jugador2]
#   [12 de 🗡️, 3 de 🗡️]
#   [12 de 🥖, 3 de 🍷]
#   [7 de 🌞, 11 de 🍷]
# 👤 jugador2 gana la ronda
#
# Puntos:
#  - 👤 jugador1: 9
#  - 👤 jugador2: 13
# --------------------
# Ronda 25 [👤 jugador1, 👤 jugador2]
#   [2 de 🥖, 5 de 🥖]
#   [6 de 🍷, 6 de 🥖]
#   [5 de 🍷, 10 de 🗡️]
#
# Puntos:
#  - 👤 jugador1: 9
#  - 👤 jugador2: 13
# --------------------
# Ronda 26 [👤 jugador1, 👤 jugador2]
#   [4 de 🌞, 12 de 🍷]
#   [3 de 🥖, 7 de 🌞]
#   [10 de 🗡️, 12 de 🗡️]
# 👤 jugador2 gana la ronda
#
# Puntos:
#  - 👤 jugador1: 9
#  - 👤 jugador2: 14
# --------------------
# Ronda 27 [👤 jugador1, 👤 jugador2]
#   [1 de 🌞, 5 de 🗡️]
#   [5 de 🍷, 12 de 🍷]
#   [10 de 🥖, 5 de 🌞]
# 👤 jugador1 gana la ronda
#
# Puntos:
#  - 👤 jugador1: 10
#  - 👤 jugador2: 14
# --------------------
# Ronda 28 [👤 jugador1, 👤 jugador2]
#   [11 de 🥖, 11 de 🌞]
#   [3 de 🗡️, 1 de 🥖]
#   [12 de 🌞, 7 de 🍷]
#
# Puntos:
#  - 👤 jugador1: 10
#  - 👤 jugador2: 14
# --------------------
# Ronda 29 [👤 jugador1, 👤 jugador2]
#   [11 de 🍷, 12 de 🍷]
#   [4 de 🍷, 1 de 🍷]
#   [2 de 🥖, 5 de 🥖]
# 👤 jugador2 gana la ronda
#
# Puntos:
#  - 👤 jugador1: 10
#  - 👤 jugador2: 15
# --------------------
# 👤 jugador2 gana la partida

# %%
def calcular_valor(numero, palo):
    pass 
class Carta:
    def __init__(self, numero, palo):
        pass 

c = Carta(1, "oro")

# %% [markdown]
# **Mazo**: Representan las cartas españolas de 1 al 12, en los palos de oro, copa, espada y basto.
#
# Debe existir una función que permita barajar las cartas.
# y otra función que permita repartir las cartas a los jugadores.

# %%
import random

class Mazo:
    def __init__(self):
        pass
    def mezclar(self):
        pass
    def repartir(self, cantidad):
        pass

m = Mazo()
m.mezclar()
print(m.repartir(3))
# Out:
# None

# %% [markdown]
# **Jugador**: Deben tener un nombre y las cartas que tiene en la mano. Debe acumular los puntos ganados.
#
# Nota: Para simplificar el problema, el jugador elige la carta a jugar de forma aleatoria.

# %%
class Jugador:
    pass
    def __init__(self, nombre):
        pass
    def recibir_cartas(self, cartas):
        pass
    
    def jugar_carta(self):
        pass

j = Jugador("Juan")
j.recibir_cartas(m.repartir(3))
print(j.jugar_carta())
# Out:
# None

# %% [markdown]
# **Partida**: Debe tener dos jugadores, un mazo de cartas y un puntaje. Debe permitir jugar una carta por ronda y definir el ganador de la ronda. Debe permitir jugar hasta que se terminen las cartas del mazo.

# %%
class Partida:
    def __init__(self, jugador1, jugador2):
        pass

    def jugar_ronda(self):

        pass 

    def jugar(self):
        # Mientras que ningun jugador acumule 15 puntos.abs
        # Mezclar el mazo
        # Repartir 3 cartas a cada jugador
        # Jugar ronda
        # Revisar quien gano la ronda
        # Sumar puntos
        pass

p = Partida(Jugador("Juan"), Jugador("Pedro"))
p.jugar()
