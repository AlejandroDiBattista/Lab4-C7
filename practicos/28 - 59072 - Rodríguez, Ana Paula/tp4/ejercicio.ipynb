# %% [markdown]
# # Simulación del Truco

# %% [markdown]
# Las **cartas** deben registra el numero, palo y valor de la carta.
# El valor debe reflejar la jerarquía de las cartas en el juego del truco.

# %%
import random
class Carta:
    def __init__(self, numero, palo):
        self.numero = numero
        self.palo = palo
        self.valor = self.calcular_valor()
    def calcular_valor(self):
        valores = {
            (1, "espada"): 14,
            (1, "basto"): 13,
            (7, "espada"): 12,
            (7, "oro"): 11,
            3: 10,
            2: 9,
            1: 8,
            12: 7,
            11: 6,
            10: 5,
            7: 4,
            6: 3,
            5: 2,
            4: 1
    }
        if (self.numero, self.palo) in valores:
            return valores[(self.numero, self.palo)]
        elif self.numero in valores:
            return valores[self.numero]
        else:
            return 0

# %% [markdown]
# **Mazo**: Representan las cartas españolas de 1 al 12, en los palos de oro, copa, espada y basto.
#
# Debe existir una función que permita barajar las cartas.
# y otra función que permita repartir las cartas a los jugadores.

# %%
import random
class Mazo:
    def __init__(self):
        self.cartas = self.generar_mazo()

    def generar_mazo(self):
        palos = ["oro", "copa", "espada", "basto"]
        numeros = [1, 2, 3, 4, 5, 6, 7, 10, 11, 12]
        cartas = []
        for palo in palos:
            for numero in numeros:
                cartas.append(Carta(numero, palo))
        return cartas
    def mezclar(self):
        random.shuffle(self.cartas)
    def repartir(self, cantidad):
        if len(self.cartas) < cantidad:
            self.cartas = self.generar_mazo()
            self.mezclar()
        return [self.cartas.pop() for _ in range(cantidad)]

# %% [markdown]
# **Jugador**: Deben tener un nombre y las cartas que tiene en la mano. Debe acumular los puntos ganados.
#
# Nota: Para simplificar el problema, el jugador elige la carta a jugar de forma aleatoria.

# %%
class Jugador:
    def __init__(self, nombre):
        self.nombre = nombre
        self.cartas = []
        self.puntos = 0
    def recibir_cartas(self, cartas):
        self.cartas = cartas
    def jugar_cartas(self):
        return self.cartas.pop(random.randint(0, len(self.cartas) - 1))

# %% [markdown]
# **Partida**: Debe tener dos jugadores, un mazo de cartas y un puntaje. Debe permitir jugar una carta por ronda y definir el ganador de la ronda. Debe permitir jugar hasta que se terminen las cartas del mazo.

# %%
class Partida:
    def __init__(self, jugador1, jugador2, puntaje_maximo=15):
        self.jugador1 = jugador1
        self.jugador2 = jugador2
        self.mazo = Mazo()
        self.puntaje_maximo = puntaje_maximo

    def jugar_ronda(self):
        carta1 = self.jugador1.jugar_cartas()
        carta2 = self.jugador2.jugar_cartas()
        print(f"{self.jugador1.nombre} juega {carta1.numero} de {carta1.palo} (Valor: {carta1.valor})")
        print(f"{self.jugador2.nombre} juega {carta2.numero} de {carta2.palo} (Valor: {carta2.valor})")
        if carta1.valor > carta2.valor:
            print(f"Ganador: {self.jugador1.nombre}")
            self.jugador1.puntos += 1
        else:
            print(f"Ganador: {self.jugador2.nombre}")
            self.jugador2.puntos += 1

    def jugar(self):
        while self.jugador1.puntos < self.puntaje_maximo and self.jugador2.puntos < self.puntaje_maximo:
            self.mazo.mezclar()  # Barajar el mazo antes de cada ronda
            self.jugador1.recibir_cartas(self.mazo.repartir(3))
            self.jugador2.recibir_cartas(self.mazo.repartir(3))
            print(f"\nNueva ronda. {self.jugador1.nombre} vs {self.jugador2.nombre}")
            for _ in range(3):
                self.jugar_ronda()
            print(f"Puntaje: {self.jugador1.nombre} {self.jugador1.puntos}, {self.jugador2.nombre} {self.jugador2.puntos}\n")
        if self.jugador1.puntos >= self.puntaje_maximo:
            print(f"{self.jugador1.nombre} ha ganado la partida!")
        else:
            print(f"{self.jugador2.nombre} ha ganado la partida!")
p = Partida(Jugador("Paula"), Jugador("Mauro"))
p.jugar()
# Out:
# Nueva ronda. Paula vs Mauro
# Paula juega 10 de basto (Valor: 5)
# Mauro juega 12 de oro (Valor: 7)
# Ganador: Mauro
# Paula juega 10 de copa (Valor: 5)
# Mauro juega 11 de espada (Valor: 6)
# Ganador: Mauro
# Paula juega 6 de oro (Valor: 3)
# Mauro juega 4 de basto (Valor: 1)
# Ganador: Paula
# Puntaje: Paula 1, Mauro 2
#
#
# Nueva ronda. Paula vs Mauro
# Paula juega 1 de basto (Valor: 13)
# Mauro juega 3 de oro (Valor: 10)
# Ganador: Paula
# Paula juega 11 de basto (Valor: 6)
# Mauro juega 12 de copa (Valor: 7)
# Ganador: Mauro
# Paula juega 6 de basto (Valor: 3)
# Mauro juega 2 de copa (Valor: 9)
# Ganador: Mauro
# Puntaje: Paula 2, Mauro 4
#
#
# Nueva ronda. Paula vs Mauro
# Paula juega 7 de copa (Valor: 4)
# Mauro juega 3 de copa (Valor: 10)
# Ganador: Mauro
# Paula juega 7 de oro (Valor: 11)
# Mauro juega 12 de basto (Valor: 7)
# Ganador: Paula
# Paula juega 12 de espada (Valor: 7)
# Mauro juega 1 de espada (Valor: 14)
# Ganador: Mauro
# Puntaje: Paula 3, Mauro 6
#
#
# Nueva ronda. Paula vs Mauro
# Paula juega 3 de basto (Valor: 10)
# Mauro juega 4 de oro (Valor: 1)
# Ganador: Paula
# Paula juega 7 de basto (Valor: 4)
# Mauro juega 6 de espada (Valor: 3)
# Ganador: Paula
# Paula juega 5 de oro (Valor: 2)
# Mauro juega 10 de espada (Valor: 5)
# Ganador: Mauro
# Puntaje: Paula 5, Mauro 7
#
#
# Nueva ronda. Paula vs Mauro
# Paula juega 2 de espada (Valor: 9)
# Mauro juega 11 de copa (Valor: 6)
# Ganador: Paula
# Paula juega 3 de espada (Valor: 10)
# Mauro juega 2 de basto (Valor: 9)
# Ganador: Paula
# Paula juega 4 de copa (Valor: 1)
# Mauro juega 5 de basto (Valor: 2)
# Ganador: Mauro
# Puntaje: Paula 7, Mauro 8
#
#
# Nueva ronda. Paula vs Mauro
# Paula juega 6 de copa (Valor: 3)
# Mauro juega 2 de oro (Valor: 9)
# Ganador: Mauro
# Paula juega 1 de oro (Valor: 8)
# Mauro juega 11 de oro (Valor: 6)
# Ganador: Paula
# Paula juega 5 de copa (Valor: 2)
# Mauro juega 4 de espada (Valor: 1)
# Ganador: Paula
# Puntaje: Paula 9, Mauro 9
#
#
# Nueva ronda. Paula vs Mauro
# Paula juega 5 de espada (Valor: 2)
# Mauro juega 5 de espada (Valor: 2)
# Ganador: Mauro
# Paula juega 1 de copa (Valor: 8)
# Mauro juega 12 de copa (Valor: 7)
# Ganador: Paula
# Paula juega 10 de oro (Valor: 5)
# Mauro juega 3 de copa (Valor: 10)
# Ganador: Mauro
# Puntaje: Paula 10, Mauro 11
#
#
# Nueva ronda. Paula vs Mauro
# Paula juega 5 de basto (Valor: 2)
# Mauro juega 2 de espada (Valor: 9)
# Ganador: Mauro
# Paula juega 10 de basto (Valor: 5)
# Mauro juega 4 de basto (Valor: 1)
# Ganador: Paula
# Paula juega 12 de oro (Valor: 7)
# Mauro juega 5 de oro (Valor: 2)
# Ganador: Paula
# Puntaje: Paula 12, Mauro 12
#
#
# Nueva ronda. Paula vs Mauro
# Paula juega 12 de espada (Valor: 7)
# Mauro juega 12 de basto (Valor: 7)
# Ganador: Mauro
# Paula juega 6 de basto (Valor: 3)
# Mauro juega 1 de oro (Valor: 8)
# Ganador: Mauro
# Paula juega 11 de copa (Valor: 6)
# Mauro juega 7 de oro (Valor: 11)
# Ganador: Mauro
# Puntaje: Paula 12, Mauro 15
#
# Mauro ha ganado la partida!
