# %% [markdown]
# # Simulación del Truco

# %% [markdown]
# Las **cartas** deben registra el numero, palo y valor de la carta.
# El valor debe reflejar la jerarquía de las cartas en el juego del truco.

# %%
def calcular_valor(numero, palo):
    jerarquia_truco = {
        (1, "espada"): 14, (1, "basto"): 13, (7, "espada"): 12, (7, "oro"): 11,
        (3, "oro"): 10, (3, "copa"): 10, (3, "espada"): 10, (3, "basto"): 10,
        (2, "oro"): 9, (2, "copa"): 9, (2, "espada"): 9, (2, "basto"): 9,
        (1, "oro"): 8, (1, "copa"): 8,
        (12, "oro"): 7, (12, "copa"): 7, (12, "espada"): 7, (12, "basto"): 7,
        (11, "oro"): 6, (11, "copa"): 6, (11, "espada"): 6, (11, "basto"): 6,
        (10, "oro"): 5, (10, "copa"): 5, (10, "espada"): 5, (10, "basto"): 5,
        (7, "copa"): 4, (7, "basto"): 4,
        (6, "oro"): 3, (6, "copa"): 3, (6, "espada"): 3, (6, "basto"): 3,
        (5, "oro"): 2, (5, "copa"): 2, (5, "espada"): 2, (5, "basto"): 2,
        (4, "oro"): 1, (4, "copa"): 1, (4, "espada"): 1, (4, "basto"): 1,
    }
    
    return jerarquia_truco.get((numero, palo), 0)

class Carta:
    def __init__(self, numero, palo):
        self.numero = numero
        self.palo = palo
        self.valor = calcular_valor(numero, palo)
    
    def __str__(self):
        return f"Carta: {self.numero} de {self.palo}, Valor: {self.valor}"

# Ejemplo de uso
c = Carta(1, "oro")
print(c)
# Out:
# Carta: 1 de oro, Valor: 8

# %% [markdown]
# **Mazo**: Representan las cartas españolas de 1 al 12, en los palos de oro, copa, espada y basto.
#
# Debe existir una función que permita barajar las cartas.
# y otra función que permita repartir las cartas a los jugadores.

# %%
import random

class Mazo:
    def __init__(self):
        self.cartas = []
        palos = ["oro", "copa", "espada", "basto"]
        for palo in palos:
            for numero in range(1, 13):
                self.cartas.append(Carta(numero, palo))
    
    def mezclar(self):
        random.shuffle(self.cartas)
    
    def repartir(self, cantidad):
        mano = self.cartas[:cantidad]
        self.cartas = self.cartas[cantidad:]
        return mano

class Carta:
    def __init__(self, numero, palo):
        self.numero = numero
        self.palo = palo
        self.valor = calcular_valor(numero, palo)
    
    def __str__(self):
        return f"Carta: {self.numero} de {self.palo}"

def calcular_valor(numero, palo):
    jerarquia_truco = {
        (1, "espada"): 14, (1, "basto"): 13, (7, "espada"): 12, (7, "oro"): 11,
        (3, "oro"): 10, (3, "copa"): 10, (3, "espada"): 10, (3, "basto"): 10,
        (2, "oro"): 9, (2, "copa"): 9, (2, "espada"): 9, (2, "basto"): 9,
        (1, "oro"): 8, (1, "copa"): 8,
        (12, "oro"): 7, (12, "copa"): 7, (12, "espada"): 7, (12, "basto"): 7,
        (11, "oro"): 6, (11, "copa"): 6, (11, "espada"): 6, (11, "basto"): 6,
        (10, "oro"): 5, (10, "copa"): 5, (10, "espada"): 5, (10, "basto"): 5,
        (7, "copa"): 4, (7, "basto"): 4,
        (6, "oro"): 3, (6, "copa"): 3, (6, "espada"): 3, (6, "basto"): 3,
        (5, "oro"): 2, (5, "copa"): 2, (5, "espada"): 2, (5, "basto"): 2,
        (4, "oro"): 1, (4, "copa"): 1, (4, "espada"): 1, (4, "basto"): 1,
    }
    return jerarquia_truco.get((numero, palo), 0)


m = Mazo()
m.mezclar()
mano = m.repartir(3)
for carta in mano:
    print(carta)
# Out:
# Carta: 3 de copa
# Carta: 7 de oro
# Carta: 10 de basto

# %% [markdown]
# **Jugador**: Deben tener un nombre y las cartas que tiene en la mano. Debe acumular los puntos ganados.
#
# Nota: Para simplificar el problema, el jugador elige la carta a jugar de forma aleatoria.

# %%
import random

class Jugador:
    def __init__(self, nombre):
        self.nombre = nombre
        self.mano = []
        self.puntos = 0
    
    def recibir_cartas(self, cartas):
        self.mano.extend(cartas)
    
    def jugar_carta(self):
        if self.mano:
            carta_jugada = random.choice(self.mano)
            self.mano.remove(carta_jugada)
            return carta_jugada
        else:
            return None
    
    def acumular_puntos(self, puntos):
        self.puntos += puntos

m = Mazo()
m.mezclar()

j = Jugador("Juan")
j.recibir_cartas(m.repartir(3))

print(f"Jugador: {j.nombre}")
print(f"Cartas en mano: {[str(carta) for carta in j.mano]}")
print(f"Carta jugada: {j.jugar_carta()}")
print(f"Cartas restantes en mano: {[str(carta) for carta in j.mano]}")
# Out:
# Jugador: Juan
# Cartas en mano: ['Carta: 12 de oro', 'Carta: 1 de oro', 'Carta: 3 de basto']
# Carta jugada: Carta: 12 de oro
# Cartas restantes en mano: ['Carta: 1 de oro', 'Carta: 3 de basto']

# %% [markdown]
# **Partida**: Debe tener dos jugadores, un mazo de cartas y un puntaje. Debe permitir jugar una carta por ronda y definir el ganador de la ronda. Debe permitir jugar hasta que se terminen las cartas del mazo.

# %%
class Mazo:
    def __init__(self):
        self.cartas = []
        palos = ["oro", "copa", "espada", "basto"]
        for palo in palos:
            for numero in range(1, 13):
                self.cartas.append(Carta(numero, palo))
    
    def mezclar(self):
       
        for i in range(len(self.cartas)):
            j = (i * 7) % len(self.cartas) 
            self.cartas[i], self.cartas[j] = self.cartas[j], self.cartas[i]
    
    def repartir(self, cantidad):
        mano = self.cartas[:cantidad]
        self.cartas = self.cartas[cantidad:]
        return mano

class Carta:
    def __init__(self, numero, palo):
        self.numero = numero
        self.palo = palo
        self.valor = calcular_valor(numero, palo)
    
    def __str__(self):
        return f"Carta: {self.numero} de {self.palo}, Valor: {self.valor}"

def calcular_valor(numero, palo):
    jerarquia_truco = {
        (1, "espada"): 14, (1, "basto"): 13, (7, "espada"): 12, (7, "oro"): 11,
        (3, "oro"): 10, (3, "copa"): 10, (3, "espada"): 10, (3, "basto"): 10,
        (2, "oro"): 9, (2, "copa"): 9, (2, "espada"): 9, (2, "basto"): 9,
        (1, "oro"): 8, (1, "copa"): 8,
        (12, "oro"): 7, (12, "copa"): 7, (12, "espada"): 7, (12, "basto"): 7,
        (11, "oro"): 6, (11, "copa"): 6, (11, "espada"): 6, (11, "basto"): 6,
        (10, "oro"): 5, (10, "copa"): 5, (10, "espada"): 5, (10, "basto"): 5,
        (7, "copa"): 4, (7, "basto"): 4,
        (6, "oro"): 3, (6, "copa"): 3, (6, "espada"): 3, (6, "basto"): 3,
        (5, "oro"): 2, (5, "copa"): 2, (5, "espada"): 2, (5, "basto"): 2,
        (4, "oro"): 1, (4, "copa"): 1, (4, "espada"): 1, (4, "basto"): 1,
    }
    return jerarquia_truco.get((numero, palo), 0)

class Jugador:
    def __init__(self, nombre):
        self.nombre = nombre
        self.mano = []
        self.puntos = 0
    
    def recibir_cartas(self, cartas):
        self.mano.extend(cartas)
    
    def jugar_carta(self):
        if self.mano:
           
            carta_jugada = self.mano[0]
            self.mano.remove(carta_jugada)
            return carta_jugada
        return None
    
    def acumular_puntos(self, puntos):
        self.puntos += puntos

class Partida:
    def __init__(self, jugador1, jugador2):
        self.jugador1 = jugador1
        self.jugador2 = jugador2
        self.mazo = Mazo()
    
    def jugar_ronda(self):
        carta_j1 = self.jugador1.jugar_carta()
        carta_j2 = self.jugador2.jugar_carta()
        
        if carta_j1 is None or carta_j2 is None:
            print("Un jugador no tiene cartas para jugar.")
            return
        
        print(f"{self.jugador1.nombre} juega: {carta_j1}")
        print(f"{self.jugador2.nombre} juega: {carta_j2}")
        
        if carta_j1.valor > carta_j2.valor:
            self.jugador1.acumular_puntos(1)
            print(f"Ronda ganada por {self.jugador1.nombre}")
        elif carta_j2.valor > carta_j1.valor:
            self.jugador2.acumular_puntos(1)
            print(f"Ronda ganada por {self.jugador2.nombre}")
        else:
            print("Empate en la ronda")
    
    def jugar(self):
        while self.jugador1.puntos < 15 and self.jugador2.puntos < 15:
            self.mazo.mezclar()
            self.jugador1.recibir_cartas(self.mazo.repartir(3))
            self.jugador2.recibir_cartas(self.mazo.repartir(3))
            
            for _ in range(3):  # Se juegan 3 rondas por mano
                self.jugar_ronda()
            
            print(f"Puntaje: {self.jugador1.nombre}: {self.jugador1.puntos}, {self.jugador2.nombre}: {self.jugador2.puntos}")
            
          
            self.jugador1.mano = []
            self.jugador2.mano = []

        if self.jugador1.puntos >= 15:
            print(f"{self.jugador1.nombre} gana la partida!")
        else:
            print(f"{self.jugador2.nombre} gana la partida!")


p = Partida(Jugador("Juan"), Jugador("Pedro"))
p.jugar()
# Out:
# Juan juega: Carta: 1 de oro, Valor: 8
# Pedro juega: Carta: 4 de oro, Valor: 1
# Ronda ganada por Juan
# Juan juega: Carta: 2 de oro, Valor: 9
# Pedro juega: Carta: 5 de oro, Valor: 2
# Ronda ganada por Juan
# Juan juega: Carta: 3 de oro, Valor: 10
# Pedro juega: Carta: 6 de oro, Valor: 3
# Ronda ganada por Juan
# Puntaje: Juan: 3, Pedro: 0
# Juan juega: Carta: 7 de basto, Valor: 4
# Pedro juega: Carta: 4 de espada, Valor: 1
# Ronda ganada por Juan
# Juan juega: Carta: 2 de copa, Valor: 9
# Pedro juega: Carta: 11 de espada, Valor: 6
# Ronda ganada por Juan
# Juan juega: Carta: 9 de copa, Valor: 0
# Pedro juega: Carta: 6 de basto, Valor: 3
# Ronda ganada por Pedro
# Puntaje: Juan: 5, Pedro: 1
# Juan juega: Carta: 7 de oro, Valor: 11
# Pedro juega: Carta: 10 de oro, Valor: 5
# Ronda ganada por Juan
# Juan juega: Carta: 8 de basto, Valor: 0
# Pedro juega: Carta: 11 de copa, Valor: 6
# Ronda ganada por Pedro
# Juan juega: Carta: 9 de oro, Valor: 0
# Pedro juega: Carta: 6 de copa, Valor: 3
# Ronda ganada por Pedro
# Puntaje: Juan: 6, Pedro: 3
# Juan juega: Carta: 1 de copa, Valor: 8
# Pedro juega: Carta: 10 de basto, Valor: 5
# Ronda ganada por Juan
# Juan juega: Carta: 8 de espada, Valor: 0
# Pedro juega: Carta: 5 de copa, Valor: 2
# Ronda ganada por Pedro
# Juan juega: Carta: 9 de espada, Valor: 0
# Pedro juega: Carta: 12 de copa, Valor: 7
# Ronda ganada por Pedro
# Puntaje: Juan: 7, Pedro: 5
# Juan juega: Carta: 7 de espada, Valor: 12
# Pedro juega: Carta: 4 de copa, Valor: 1
# Ronda ganada por Juan
# Juan juega: Carta: 2 de basto, Valor: 9
# Pedro juega: Carta: 11 de oro, Valor: 6
# Ronda ganada por Juan
# Juan juega: Carta: 9 de basto, Valor: 0
# Pedro juega: Carta: 12 de oro, Valor: 7
# Ronda ganada por Pedro
# Puntaje: Juan: 9, Pedro: 6
# Juan juega: Carta: 1 de basto, Valor: 13
# Pedro juega: Carta: 10 de copa, Valor: 5
# Ronda ganada por Juan
# Juan juega: Carta: 8 de copa, Valor: 0
# Pedro juega: Carta: 11 de basto, Valor: 6
# Ronda ganada por Pedro
# Juan juega: Carta: 3 de copa, Valor: 10
# Pedro juega: Carta: 6 de espada, Valor: 3
# Ronda ganada por Juan
# Puntaje: Juan: 11, Pedro: 7
# Juan juega: Carta: 7 de copa, Valor: 4
# Pedro juega: Carta: 4 de basto, Valor: 1
# Ronda ganada por Juan
# Juan juega: Carta: 8 de oro, Valor: 0
# Pedro juega: Carta: 5 de espada, Valor: 2
# Ronda ganada por Pedro
# Juan juega: Carta: 3 de espada, Valor: 10
# Pedro juega: Carta: 12 de espada, Valor: 7
# Ronda ganada por Juan
# Puntaje: Juan: 13, Pedro: 8
# Juan juega: Carta: 1 de espada, Valor: 14
# Pedro juega: Carta: 10 de espada, Valor: 5
# Ronda ganada por Juan
# Juan juega: Carta: 2 de espada, Valor: 9
# Pedro juega: Carta: 5 de basto, Valor: 2
# Ronda ganada por Juan
# Juan juega: Carta: 3 de basto, Valor: 10
# Pedro juega: Carta: 12 de basto, Valor: 7
# Ronda ganada por Juan
# Puntaje: Juan: 16, Pedro: 8
# Juan gana la partida!
